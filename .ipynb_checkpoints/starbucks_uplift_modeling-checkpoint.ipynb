# %% [markdown]
# ## Uplift Modeling
#
# Uplift modelling, also known as **incremental modelling, true lift modelling, or net modelling** is a predictive modelling technique that directly models the incremental impact of a treatment (such as a direct marketing action) on an individual's behaviour.
#
# Uplift modelling has applications in customer relationship management for up-sell, cross-sell and retention modelling. It has also been applied to political election and personalised medicine. Unlike the related Differential Prediction concept in psychology, Uplift Modelling assumes an active agent.
#
# One of the most critical jobs of Growth Hacker is to be efficient by all means as much as possible. First of all, you need to be time-efficient. That means you have to quickly ideate, experiment, learn and re-iterate. Second, you need to be cost-efficient. It means bringing the maximum return for a given budget/time/effort.
#
# Uplift modelling uses a randomised scientific control to not only measure the effectiveness of an action but also to build a predictive model that predicts the incremental response to the action. It is a data mining technique that has been applied predominantly in the financial services, telecommunications and retail direct marketing industries to up-sell, cross-sell, churn and retention activities.
#
# Segmentation helps Growth Hackers to increase conversion and hence be cost-efficient.
#
# We can summarize the segments based on this approach like below:
#
# - Treatment Responders: Customers that will purchase only if they receive an offer
# - Treatment Non-Responders: Customer that won’t purchase in any case
# - Control Responders: Customers that will purchase without an offer
# - Control Non-Responders: Customers that will not purchase if they don’t receive an offer
#
# The picture is very obvious. You need to target Treatment Responders (TR) and Control Non-Responders (CN). Since they won’t purchase unless you give an offer, these groups are boosting your uplift in promotional campaigns. On the other hand, you need to avoid targeting Treatment Non-Responders (TN) and Control Responders (CR). You will not benefit from targeting TN and, CN will make you cannibalize.
#
# Uplift Modeling has two simple steps:
# - Predict the probabilities of being in each group for all customers: we are going to build a multi-classification model for that.
# - We will calculate the uplift score. Uplift score formula is:
#
# ![medium_image](https://miro.medium.com/max/3000/1*AvNi0acKGyCs7jYsqcfl_w.png)
#
# There are several apporaches for uplift modeling:
#
#    - Traditional one model approach: This method predicts only customers who received promotions and completed the offer or purchased. The issue with this approach is that it discards the control group data.
#
#    - Two model Uplift Approach: create 2 models to predict the purchases from the treatment and the control group respectively. The difference in the predicted probabilities of these models represents the lift value which can be used as a cutoff point for the customers responsive to promotions. The issue with this model is that lifts indirectly.
#
#    - Four quadrant approach: split the customers into 4 Groups(treatment response: TR, treatment no response TN, control response CR, control no response CN). then build a model to predict the label the customer belongs to. The promotions can be either sent to only TR(sure thing to respond to promotion) or we can create an uplift score to divide the customer based on the probability of belonging to certain groups and use cut off to decide when to send a promotion or no.
#
# **NIR(Net Incremental Revenue):** NIR depicts how much is made (or lost) by sending out the promotion. Mathematically, this is 10 times the total number of purchasers that received the promotion minus 0.15 times the number of promotions sent out, minus 10 times the number of purchasers who were not given the promotion. **NIR = Uplift Score mentioned above.**
#
# We will sum up the probability of being TR and CN and subtract the probability of falling into other buckets. The higher score means higher uplift.
#
# [Source : Medium](https://towardsdatascience.com/uplift-modeling-e38f96b1ef60)

# %% [markdown]
# ### Creating different datasets for different offer types.
#
# *Since, uplift modeling determines how a targeted ads and offers work on each customer, we should split datasets into multiple with factor of offer type.*

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %matplotlib inline

# %%
customer_transactions = pd.read_csv('data/customer_transaction_data_categorical.csv')

# %%
# converting became_member on to datetime
customer_transactions.became_member_on = pd.to_datetime(customer_transactions.became_member_on)

# %%
customer_transactions.sample(5)
# Out:
#                             customer_id  time_received  \
# 29546  747f706b685144b29bbc8a0f209432ec             14
# 18284  47ca45c8529e43f29d9a2f285d07ffbe              0
# 10798  2c2af24d040a41b6829e4239c812dbac              7
# 5736   174f1571d41543d4b11cc523342352a2              7
# 36481  8eff47d0d9164301982fac938da935e0              0
#
#                                offer_id  reward  age became_member_on  \
# 29546  2906b810c7d4411798c6938adc9daaa5     2.0   79       2018-06-18
# 18284  0b1e1539f2cc45b7b9fa7c272da2e1d7     0.0   35       2017-07-03
# 10798  ae264e3637204a6fb9bb56bc8210ddfd     0.0   52       2015-08-29
# 5736   5a8bc65990b245e5a138643cd4eb9837     0.0   50       2017-09-26
# 36481  5a8bc65990b245e5a138643cd4eb9837     0.0   72       2016-12-17
#
#         income  difficulty  duration     offer_type  ...  revenue_cluster  \
# 29546  77000.0        10.0       7.0       discount  ...                2
# ...

# %%
customer_transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65020 entries, 0 to 65019
# Data columns (total 46 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   customer_id                  65020 non-null  object
#  1   time_received                65020 non-null  int64
#  2   offer_id                     65020 non-null  object
#  3   reward                       65020 non-null  float64
#  4   age                          65020 non-null  int64
#  5   became_member_on             65020 non-null  datetime64[ns]
#  6   income                       65020 non-null  float64
#  7   difficulty                   65020 non-null  float64
#  8   duration                     65020 non-null  float64
#  9   offer_type                   65020 non-null  object
#  10  email                        65020 non-null  float64
#  11  mobile                       65020 non-null  float64
# ...

# %% [markdown]
# #### Splitting with offer types and offer ids.

# %%
customer_transactions.offer_type.unique()
# Out:
# array(['discount', 'informational', 'bogo'], dtype=object)

# %%
customer_transactions.offer_id.unique()
# Out:
# array(['2906b810c7d4411798c6938adc9daaa5',
#        '3f207df678b143eea3cee63160fa8bed',
#        '5a8bc65990b245e5a138643cd4eb9837',
#        'f19421c1d4aa40978ebb69ca19b0e20d',
#        'fafdcd668e3743c1bb461111dcafc2a4',
#        '0b1e1539f2cc45b7b9fa7c272da2e1d7',
#        '2298d6c36e964ae4a3e7e9706d1fb8c2',
#        '9b98b8c7a33c4b65b9aebfe6a799e6d9',
#        '4d5c57ea9a6940dd891ad53e9dbe8da0',
#        'ae264e3637204a6fb9bb56bc8210ddfd'], dtype=object)

# %%
# offer_ids with bogo
customer_transactions[customer_transactions.offer_type == 'bogo'].offer_id.unique()
# Out:
# array(['f19421c1d4aa40978ebb69ca19b0e20d',
#        '9b98b8c7a33c4b65b9aebfe6a799e6d9',
#        '4d5c57ea9a6940dd891ad53e9dbe8da0',
#        'ae264e3637204a6fb9bb56bc8210ddfd'], dtype=object)

# %%
# offer_ids with informational
customer_transactions[customer_transactions.offer_type == 'informational'].offer_id.unique()
# Out:
# array(['3f207df678b143eea3cee63160fa8bed',
#        '5a8bc65990b245e5a138643cd4eb9837'], dtype=object)

# %%
# offer_ids with discount
customer_transactions[customer_transactions.offer_type == 'discount'].offer_id.unique()
# Out:
# array(['2906b810c7d4411798c6938adc9daaa5',
#        'fafdcd668e3743c1bb461111dcafc2a4',
#        '0b1e1539f2cc45b7b9fa7c272da2e1d7',
#        '2298d6c36e964ae4a3e7e9706d1fb8c2'], dtype=object)

# %% [markdown]
# **We need a way to distinguish between multiple bogo offer id, Since each offer id have different difficulty, duration and reward, we can use this information.**

# %%
# removing reward = 0 because it will show records who made transaction but didn't get reward.
customer_transactions[customer_transactions.reward != 0][['offer_id', 'offer_type', 'difficulty', 'duration', 'reward']].drop_duplicates('offer_id').sort_values('offer_type').reset_index(drop = True)
# Out:
#                            offer_id offer_type  difficulty  duration  reward
# 0  f19421c1d4aa40978ebb69ca19b0e20d       bogo         5.0       5.0     5.0
# 1  9b98b8c7a33c4b65b9aebfe6a799e6d9       bogo         5.0       7.0     5.0
# 2  4d5c57ea9a6940dd891ad53e9dbe8da0       bogo        10.0       5.0    10.0
# 3  ae264e3637204a6fb9bb56bc8210ddfd       bogo        10.0       7.0    10.0
# 4  2906b810c7d4411798c6938adc9daaa5   discount        10.0       7.0     2.0
# 5  fafdcd668e3743c1bb461111dcafc2a4   discount        10.0      10.0     2.0
# 6  0b1e1539f2cc45b7b9fa7c272da2e1d7   discount        20.0      10.0     5.0
# 7  2298d6c36e964ae4a3e7e9706d1fb8c2   discount         7.0       7.0     3.0

# %%
customer_transactions[customer_transactions.offer_type == 'informational'][['offer_id', 'offer_type', 'difficulty', 'duration', 'reward']].drop_duplicates('offer_id').sort_values('offer_type').reset_index(drop = True)
# Out:
#                            offer_id     offer_type  difficulty  duration  \
# 0  3f207df678b143eea3cee63160fa8bed  informational         0.0       4.0
# 1  5a8bc65990b245e5a138643cd4eb9837  informational         0.0       3.0
#
#    reward
# 0     0.0
# 1     0.0

# %% [markdown]
# ### Creating Multiple Datasets for each offer.
#
# We need something to differentiate between them, so we will use duration, difficulty and reward for naming convention.
#
# Datasets to be made:
# - bogo_555
# - bogo_575
# - bogo_10510
# - bogo_10710
# - discount_1072
# - discount_10102
# - discount_20105
# - discount_773

# %%
customer_transactions.insert(5, 'year', customer_transactions.became_member_on.dt.year)
customer_transactions.insert(5, 'month', customer_transactions.became_member_on.dt.month)
customer_transactions.insert(5, 'day', customer_transactions.became_member_on.dt.day)
customer_transactions.insert(5, 'weekday', customer_transactions.became_member_on.dt.weekday)
customer_transactions.drop('became_member_on', inplace=True, axis = 1)

# %%
bogo_555 = customer_transactions[customer_transactions.offer_id == 'f19421c1d4aa40978ebb69ca19b0e20d']
bogo_575 = customer_transactions[customer_transactions.offer_id == '9b98b8c7a33c4b65b9aebfe6a799e6d9']
bogo_10510 = customer_transactions[customer_transactions.offer_id == '4d5c57ea9a6940dd891ad53e9dbe8da0']
bogo_10710 = customer_transactions[customer_transactions.offer_id == 'ae264e3637204a6fb9bb56bc8210ddfd']
discount_1072 = customer_transactions[customer_transactions.offer_id == '2906b810c7d4411798c6938adc9daaa5']
discount_10102 = customer_transactions[customer_transactions.offer_id == 'fafdcd668e3743c1bb461111dcafc2a4']
discount_20105 = customer_transactions[customer_transactions.offer_id == '0b1e1539f2cc45b7b9fa7c272da2e1d7']
discount_773 = customer_transactions[customer_transactions.offer_id == '2298d6c36e964ae4a3e7e9706d1fb8c2']
informational_040 = customer_transactions[customer_transactions.offer_id == '3f207df678b143eea3cee63160fa8bed']
informational_030 = customer_transactions[customer_transactions.offer_id == '5a8bc65990b245e5a138643cd4eb9837']

# %%
bogo_555.sample(5)
# Out:
#                             customer_id  time_received  \
# 16871  42b08cfe20c54e15ab6815c4a1d9d2cf             17
# 53889  d3bffca55668437d89226db69907b705              0
# 12763  330cfed337f84788b32ebd5d4702a7b3             24
# 54928  d83cd73288d34f7d894d1d4ce23dd3a5              7
# 38664  979b2f7c5caa40be87ca906ecab52491             14
#
#                                offer_id  reward  age  weekday  day  month  \
# 16871  f19421c1d4aa40978ebb69ca19b0e20d     0.0   31        3   21      9
# 53889  f19421c1d4aa40978ebb69ca19b0e20d     5.0   90        3   27      8
# 12763  f19421c1d4aa40978ebb69ca19b0e20d     5.0   22        3    1      1
# 54928  f19421c1d4aa40978ebb69ca19b0e20d     5.0   23        0   26      9
# 38664  f19421c1d4aa40978ebb69ca19b0e20d     5.0   55        6   11     10
#
#        year    income  ...  revenue_cluster  frequency frequency_cluster  \
# 16871  2017   33000.0  ...                3          7                 3
# ...

# %% [markdown]
# #### Uplift Modeling

# %%
def uplift_score(model, test, all_promoted=False):
    if all_promoted == True:
        promoted = np.array([1] * test.shape[0])
        return promoted
    else:
        class_probs = model.predict_proba(test)
        uplift_score = class_probs[:,0] + class_probs[:,3] - class_probs[:,1] - class_probs[:,2]
        promotion = []
        
        for score in uplift_score:
            if score > 0 :
                promotion.append(1)
            else:
                promotion.append(0)

        promotion = np.array(promotion)
        return promotion
    
def results(X_test, y_test, model, all_promoted=False):

    data = pd.concat([X_test, y_test], axis=1)

    promos = uplift_score(model, X_test, all_promoted)
    
    promoted_data = data.iloc[np.where(promos == 1)]

    # treatment group are the group who view the offer (TR, TN) 
    # control group are the group who didn't view the offer (CR, CN)
    treatment = promoted_data[promoted_data.segment.isin([0,1])].shape[0]
    
    control = promoted_data[promoted_data.segment.isin([2,3])].shape[0]
    
    treatment_complete = promoted_data[promoted_data.segment.isin([0])].shape[0]
    control_complete = promoted_data[promoted_data.segment.isin([2])].shape[0]
    
    # revenue is total spent for each group
     
    treatment_revenue = promoted_data[promoted_data.segment.isin([0, 1])].profit.sum()
    control_revenue = promoted_data[promoted_data.segment.isin([2, 3])].total_spent_non_offer.sum()
    
    rate_of_return = (treatment_complete / treatment) - (control_complete / control)
    
    nir = treatment_revenue - control_revenue 
    return nir, rate_of_return

# %%
def train_test_data(dataset, target):
    data = dataset.copy()
    if 'offer_type' in set(data.columns):
        data.drop(columns=['offer_id', 'customer_id', 'offer_type'], inplace=True, axis = 1)
    else:
        data.drop(columns=['offer_id', 'customer_id'], inplace=True, axis = 1)
        
    X = data.drop(target, axis=1)
    y = data[target]

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)

    return X_train, y_train, X_val, y_val, X_test, y_test

def namestr(obj, namespace):
    return [name for name in namespace if namespace[name] is obj]

def uplift_model(data, target, plot_importance = False, calculate_results = False):
    X_train, y_train, X_val, y_val, X_test, y_test = train_test_data(data, target)
    
    # SMOTE analysis
    smote = SMOTE(sampling_strategy={0:max(y_train.value_counts()[:]), 1:max(y_train.value_counts()[:]), 2:max(y_train.value_counts()[:]),\
     3:max(y_train.value_counts()[:])}, random_state=42)

    X_train_oversample, y_train_oversample = smote.fit_resample(X_train, y_train)

    X_train_oversample = pd.DataFrame(X_train_oversample)

    y_train_oversample = pd.Series(y_train_oversample)

    model = RandomForestClassifier(random_state=42)

    model.fit(X_train_oversample, y_train_oversample.values.ravel())
     
    predictions = model.predict(X_val)
    test_predictions = model.predict(X_test)
    test_report = classification_report(y_test, test_predictions, target_names=['TR', 'CR', 'TN', 'CN'])
    
    print(f'\n*********************************************{namestr(data, globals())}**************************************************************')
    print('Test Report : \n', test_report)
    
    print('Confusion Matrix of testing: \n', confusion_matrix(y_test, test_predictions))
    
    print('Accuracy of Validation : ', accuracy_score(y_val, predictions))
    print('Accuracy of Testing : ', accuracy_score(y_test, test_predictions))
    
    if plot_importance == True:
        importances = model.feature_importances_
        sorted_indices = np.argsort(importances)[::-1]
        plt.figure(figsize=(15, 9))
        plt.title('Feature Importance')
        plt.bar(range(X_train.shape[1]), importances[sorted_indices], align='center')
        plt.xticks(range(X_train.shape[1]), X_train.columns[sorted_indices], rotation=90)
        plt.tight_layout()
        plt.show()
        
    if calculate_results == True:
        nir, rate_of_return = results(X_test, y_test, model, all_promoted=False)
        print('Net Incemental Revenue (NIR) if promoted only to high uplift score : ', nir)
        print('Rate of Return if only promoted to high uplift score : ', rate_of_return)
        
        nir, rate_of_return = results(X_test, y_test, model, all_promoted=True)
        print('Net Incemental Revenue (NIR) if promoted to all : ', nir)
        print('Rate of Return if only promoted to all : ', rate_of_return)

# %%
uplift_model(bogo_555, 'segment', plot_importance=True, calculate_results=True)
# Out:
# *********************************************['bogo_555']**************************************************************
# Test Report :
#                precision    recall  f1-score   support
#
#           TR       1.00      1.00      1.00       906
#           CR       1.00      1.00      1.00       559
#           TN       1.00      1.00      1.00       119
#           CN       1.00      1.00      1.00        22
#
#     accuracy                           1.00      1606
#    macro avg       1.00      1.00      1.00      1606
# weighted avg       1.00      1.00      1.00      1606
#
# Confusion Matrix of testing:
#  [[906   0   0   0]
#  [  0 559   0   0]
#  [  0   0 119   0]
#  [  0   0   0  22]]
# Accuracy of Validation :  1.0
# Accuracy of Testing :  1.0
# Net Incemental Revenue (NIR) if promoted only to high uplift score :  37292.67
# Rate of Return if only promoted to high uplift score :  1.0
# Net Incemental Revenue (NIR) if promoted to all :  34545.07
# ...

# %%
datasets = [bogo_555, bogo_575, bogo_10510, bogo_10710, discount_1072, discount_10102, discount_20105, discount_773]

for dataset in datasets:
    uplift_model(dataset, 'segment', plot_importance=True, calculate_results=True)
# Out:
# *********************************************['bogo_555', 'dataset']**************************************************************
# Test Report :
#                precision    recall  f1-score   support
#
#           TR       1.00      1.00      1.00       906
#           CR       1.00      1.00      1.00       559
#           TN       1.00      1.00      1.00       119
#           CN       1.00      1.00      1.00        22
#
#     accuracy                           1.00      1606
#    macro avg       1.00      1.00      1.00      1606
# weighted avg       1.00      1.00      1.00      1606
#
# Confusion Matrix of testing:
#  [[906   0   0   0]
#  [  0 559   0   0]
#  [  0   0 119   0]
#  [  0   0   0  22]]
# Accuracy of Validation :  1.0
# Accuracy of Testing :  1.0
# Net Incemental Revenue (NIR) if promoted only to high uplift score :  37292.67
# Rate of Return if only promoted to high uplift score :  1.0
# Net Incemental Revenue (NIR) if promoted to all :  34545.07
# ...

# %% [markdown]
# #### Checking by fitting all the dataset.

# %%
customer_transactions_temp = customer_transactions.copy()

customer_transactions_temp = pd.get_dummies(customer_transactions_temp, columns=['offer_type'])

# %%
uplift_model(customer_transactions_temp, 'segment', plot_importance=True, calculate_results=True)
# Out:
# *********************************************['customer_transactions_temp']**************************************************************
# Test Report :
#                precision    recall  f1-score   support
#
#           TR       1.00      1.00      1.00      7504
#           CR       1.00      1.00      1.00      3718
#           TN       1.00      0.99      1.00      2299
#           CN       1.00      1.00      1.00      2734
#
#     accuracy                           1.00     16255
#    macro avg       1.00      1.00      1.00     16255
# weighted avg       1.00      1.00      1.00     16255
#
# Confusion Matrix of testing:
#  [[7503    0    1    0]
#  [   0 3718    0    0]
#  [  20    0 2279    0]
#  [   0    0    0 2734]]
# Accuracy of Validation :  0.9983595800524935
# Accuracy of Testing :  0.9987080898185173
# Net Incemental Revenue (NIR) if promoted only to high uplift score :  332469.57999999996
# ...

# %% [markdown]
# # Conculsion
#
# *The uplift modeling approach was presented as a way to study the customer's response to offers. The current promotion strategy was to send offers to all the customers, this is a wasteful approach and costly since not all customers respond equally to offers. Additionally, RFM clustering was used in the model features and to segment the customer on purchasing behavior.*
#
# **Customer Details:**
#
# - Income: Most people are in the 50k-60k income-range and 90% of customers have income less than 90k.
# - Gender: 57% male users compared to 41% Females with 2% females.
# - Age: The age group with the highest percentage in the members is 48–58, the smaller group consists of the older generation (88–98).
#
# **RFM Segments and Customer Groups**
#
# - RFM Segments Distribution: 42% of the customers are in the Low-value RFM group followed by the Mid-value RFM group, and the High RFM group with 15% of customers.
# - Customer Groups Distribution: 45% of the customers are in the Treatment response(TR) while the CR group had 14.3% of the customers.
# - Gender in the RFM segments: The Males are present in the mid-value and low-value RFM while the females have a higher percentage in the low-value segment.
#
# **The Purchasing Behavior in RFM Clusters**
#
# - Total spent vs RFM segment: There was a clear difference between the different segments in terms of amount spent.
# - Customer segments vs RFM clusters: The mid and low-value segments had higher percentages of the response compared to the high-value segment. This indicates that high and mid-value customers are responsive to targeted marketing while it did not make a difference in the Low values.
#
# **Customer Groups vs Segment**
#
# - Income vs Customer Segment: The highest income customers are in TR or CR group.
# - Total Spent vs customer segment: The difference in the amount of money spent between the treatment and control groups is significant.
#
# **Uplift Modeling**
#
# - The proposed promotion strategy gave a better rate of return than the base strategy which means promoting to all customers.
# - It is clear from the results that promoting to everyone is bad idea which give -ve rate of return.
# - Promoting to high uplift score customers will retain the same rate of return.
# - In some cases, rate of return will go less than 1.
